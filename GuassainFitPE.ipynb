# %%
import pandas as pd
import numpy as np
import h5py
import analysis_data
run_info =[]

# %%
# file = 'outnpy/lv2415_lv2414_20241105_LED_2.0v_900mv_1p9_1p325_100ns_run0.h5df'
# file = 'outnpy/lv2415_lv2414_20241105_LED_2.0v_900mv_1p9_1p325_1us_run0.h5df'
# file = 'outnpy/lv2415_lv2414_20241105_LED_2.0v_900mv_1p9_1p325_5us_run0.h5df'

##################################
# file  = 'outnpy/lv2415_lv2414_20241105_9DB_LED_3.0v_900mv_2p4_1p36_5us_run0.h5df'
# file  = 'outnpy/lv2415_lv2414_20241105_9DB_LED_3.0v_900mv_2p4_1p36_10us_run0.h5df'
# file  = 'outnpy/lv2415_lv2414_20241105_9DB_LED_3.0v_900mv_2p4_1p36_30us_run0.h5df'
# file  = 'outnpy/lv2415_lv2414_20241105_9DB_LED_3.0v_900mv_2p4_1p36_90us_run4.h5df'
# file  = 'outnpy/lv2415_lv2414_20241105_9DB_LED_3.0v_900mv_2p4_1p36_200us_run0.h5df'

# file  = 'outnpy/lv2415_lv2414_20241107_9DB_LED_3.0v_900mv_2p4_1p36_200us_run0.h5df'
################################
# file  = 'outnpy/lv2415_lv2414_20241107_9DB_LED_4.0v_900mv_2p9_1p36_5us_run0.h5df'
# file = 'outnpy/lv2415_lv2414_20241107_9DB_LED_4.0v_900mv_2p9_1p36_10us_run0.h5df'
# file =  'outnpy/lv2415_lv2414_20241107_9DB_LED_4.0v_900mv_2p9_1p36_30us_run0.h5df'
#################################
# file = 'outnpy/lv2415_lv2414_20241111_9DB_LED_2.0v_900mv_1p9_1p36_5us_run0.h5df'
# file = 'outnpy/lv2415_lv2414_20241111_9DB_LED_2.0v_900mv_1p9_1p36_10us_run0.h5df'
# file = 'outnpy/lv2415_lv2414_20241111_9DB_LED_2.0v_900mv_1p9_1p36_30us_run0.h5df'
# file = 'outnpy/lv2415_lv2414_20241111_9DB_LED_2.0v_900mv_1p9_1p36_90us_run0.h5df'
# file = 'outnpy/lv2415_lv2414_20241111_9DB_LED_2.0v_900mv_1p9_1p36_200us_run0.h5df'
##############################
# file = 'outnpy/lv2415_lv2414_20241113_12DB_LED_1.6v_900mv_1p9_1p36_5us_run0_raw_b0_seg0.h5py'
# file = 'outnpy/lv2415_lv2414_20241113_12DB_LED_1.6v_900mv_1p9_1p36_10us_run0_raw_b0_seg0.h5py'
# file = 'outnpy/lv2415_lv2414_20241113_12DB_LED_1.6v_900mv_1p9_1p36_30us_run0_raw_b0_seg1.h5py'
# file =   'outnpy/lv2415_lv2414_20241113_12DB_LED_1.6v_900mv_1p9_1p36_90us_run0_raw_b0_seg0.h5py'
file = 'outnpy/lv2415_lv2414_20241113_12DB_LED_1.6v_900mv_1p9_1p36_200us_run0_raw_b0_seg0.h5py'

# %%
# file_date = file.split('LED_')[0].split('9DB_')[1]
file_date = file.split('LED_')[0].split('lv2414_')[1]
led_config = file.split('LED_')[1].split('_raw')[0]
# led_config = file.split('LED_')[1].split('.h5df')[0]
file_tag = file_date + led_config
file_tag
# Out:
# '20241113_12DB_1.6v_900mv_1p9_1p36_200us_run0'

# %%
path = 'outnpy/lv2415_lv2414_20241113_12DB_LED_1.6v_900mv_1p9_1p36_200us_run0_raw_b0_seg0.h5py'
df0 = pd.read_hdf(path, key='winfo')
path = 'outnpy/lv2415_lv2414_20241113_12DB_LED_1.6v_900mv_1p9_1p36_200us_run0_raw_b0_seg1.h5py'
df1 = pd.read_hdf(path, key='winfo')
path = 'outnpy/lv2415_lv2414_20241113_12DB_LED_1.6v_900mv_1p9_1p36_200us_run0_raw_b0_seg2.h5py'
df2 = pd.read_hdf(path, key='winfo')
path = 'outnpy/lv2415_lv2414_20241113_12DB_LED_1.6v_900mv_1p9_1p36_200us_run0_raw_b0_seg3.h5py'
df3 = pd.read_hdf(path, key='winfo')
path = 'outnpy/lv2415_lv2414_20241113_12DB_LED_1.6v_900mv_1p9_1p36_200us_run0_raw_b0_seg5.h5py'
df4 = pd.read_hdf(path, key='winfo')

# %%
df = pd.concat([df0, df1, df2,df3,df4])
# df = pd.read_hdf(file, key='winfo')
df.head()
# Out:
#    Ch      TTT  Baseline       Area_S1       Area_S2  S1_width  S2_width  \
# 0   0    60372     15170  22853.581391  21242.828219       152       920
# 1   1    60372     15312   2768.097433    279.545623       152       920
# 2   2    60372      8113  -2416.192104   -261.688370       152       920
# 3   0  1310364     15171  22876.990912  21177.746783       152       920
# 4   1  1310364     15312   2898.721724    264.371997       152       920
#
#    Delta_t                                               Wave
# 0      200  [15169, 15172, 15176, 15170, 15173, 15172, 151...
# 1      200  [15316, 15312, 15314, 15311, 15314, 15313, 153...
# 2      200  [8109, 8116, 8115, 8112, 8114, 8114, 8113, 811...
# 3      200  [15168, 15172, 15170, 15168, 15174, 15171, 151...
# 4      200  [15313, 15313, 15309, 15313, 15316, 15312, 153...

# %%
# n =0
# ch_0 = df.Ch[:][n]
# wave_0 = df.Wave[:][n]
# baseline_0 = df.Baseline[:][n]
# ttt_0 =  df.TTT[:][n]
# area_0 = df.Area_S2[:][n]

# # # m =2
# # # ch_1 = df.Ch[:][m]
# # # wave_2 = df.Wave[:][m]
# # # baseline_2 = df.Baseline[:][m]
# # # ttt_2 = df.TTT[:][m]
# # # area_2 = df.Area_S1[:][m]

# %%
# analysis_data.plot_waveform(wave_0, baseline_0, 90, 130, 120, 000,200,pmt='2415',ch=r'Ch={}'.format(ch_0), ttt=ttt_0, area=area_0)
# # analysis_data.plot_waveform(wave_0, baseline_0, 90,130, 120, 7500, 8000, pmt='LV2414', ch=r'Ch={}'.format(ch_0),  ttt=ttt_0, area=area_0)

# %%
# import matplotlib.pyplot as plt
# plt.figure()
# plt.plot(df.Wave.iloc[2], label='1us')
# # plt.step(np.arange(len(df.Wave.iloc[0])), df.Wave, where='mid')
# # plt.step(np.arange(len(wave_1p325_1us)), wave_1p325_1us, where='mid')
# # plt.step(np.arange(len(wave_1p5_1p325_1us)), wave_1p5_1p325_1us, where='mid')
# # plt.step(np.arange(len(wave_1p5_1p325_500ns)), wave_1p5_1p325_500ns, where='mid')
# # plt.axhline(y=14300, color='b', linestyle='--', label='Baseline')  # 基线
# plt.axhline(y=baseline_0, color='b', linestyle='--', label='Threshold')  # 阈值
# # plt.axvline(x=375, color='r', linestyle='--', label='')# 阈值
# # plt.axvline(x=455, color='r', linestyle='--', label='')# 阈值

# # plt.scatter(st, wave[st], color='r', marker='o', label='start')  # 起始点
# # plt.scatter(ed, wave[ed], color='g', marker='o', label='end')  # 结束点
# # plt.scatter(lp, wave[lp], color='b', marker='o', label='minpoint')  # 最低点
# # plt.title(r'Waveform of PMT {} {}, TTT={}, {:.2f}PE'.format(pmt,ch, ttt, area))
# plt.xlabel('Time [4 ns]')
# plt.ylabel('ADC Count')
# # plt.title('Anode S1 waveform 2341.1893 PE/ns in average')
# plt.legend()
# # plt.xlim(0,300)
# # plt.xlim(1275,1750)  # 5us
# # plt.xlim(2500,3000)  # 10us
# # plt.xlim(7500,8000) # 30us
# plt.xlim(25500, 25000) #90us
# # plt.xlim(50000, 50500) #200us
# plt.ylim(12500,16000)
# plt.show()

# %%
# wave_1p325_1us = wave_1p325_1us[80:380]
# wave_1p5_1p325_1us =  wave_0[360:660]
# wave_1p5_1p325_500ns =  wave_0[230:530]
# wave_1p5_1p325_300ns =  wave_0[180:480]
# wave_1p5_1p325_100ns = wave_0[130:430]
# wave_1p9_1p325_5uns  = wave_0[1300:1700]

# %%
area_ch0_s1 = df.Area_S1[df.Ch==0 ].astype(np.float64).to_numpy()
area_ch1_s1 = df.Area_S1[df.Ch==1 ].astype(np.float64).to_numpy()
area_ch2_s1 = df.Area_S1[df.Ch==2 ].astype(np.float64).to_numpy()

area_ch0_s2 = df.Area_S2[df.Ch==0 ].astype(np.float64).to_numpy()
area_ch1_s2 = df.Area_S2[df.Ch==1 ].astype(np.float64).to_numpy()
area_ch2_s2 = df.Area_S2[df.Ch==2 ].astype(np.float64).to_numpy()

# %%
mean_ch0 = np.mean(area_ch0_s1)
std_ch0 = np.std(area_ch0_s1)
nbins_ch0 = round(np.max(area_ch0_s1)-np.min(area_ch0_s1))
left_edge_ch0 = np.min(area_ch0_s1)
right_edge_ch0 = np.max(area_ch0_s1)
amplitude_ch0 = len(area_ch0_s1)

mean_ch1 = np.mean(area_ch1_s1)
std_ch1 = np.std(area_ch1_s1)
nbins_ch1 = round(np.max(area_ch1_s1)-np.min(area_ch1_s1))
left_edge_ch1 = np.min(area_ch1_s1)
right_edge_ch1 = np.max(area_ch1_s1)
amplitude_ch1 = len(area_ch1_s1)

mean_ch2 = np.mean(-area_ch2_s1)
std_ch2 = np.std(-area_ch2_s1)
nbins_ch2 = round(np.max(-area_ch2_s1)-np.min(-area_ch2_s1))
left_edge_ch2 = np.min(-area_ch2_s1)
right_edge_ch2 = np.max(-area_ch2_s1)
amplitude_ch2 = len(-area_ch2_s1)

# %%
Ch0_s1_mu, Ch0_s1_sigma =  analysis_data.plot_fit_histgram_vs_Gaussion(area_ch0_s1, 100,left_edge_ch0, right_edge_ch0 , [amplitude_ch0, mean_ch0, std_ch0 ], file_tag=file_tag, xlabel='Ch0 Area (PE)', title='lv2414_ch0_s1',Save=False)
# Out:
# Fit: mu= 22808.04, sigma =62.01

# %%
Ch1_s1_mu, Ch1_s1_sigma =  analysis_data.plot_fit_histgram_vs_Gaussion(area_ch1_s1, 100, left_edge_ch1 , right_edge_ch1 , [amplitude_ch1, mean_ch1, std_ch1 ], file_tag=file_tag, xlabel='Ch1 Area (PE)', title='lv2414 Ch1 s1 ')
# Out:
# Fit: mu= 2761.91, sigma =53.16

# %%
Ch2_s1_mu, Ch2_s1_sigma =  analysis_data.plot_fit_histgram_vs_Gaussion(-area_ch2_s1, 100, left_edge_ch2 ,right_edge_ch2, [amplitude_ch2, mean_ch2, std_ch2 ], file_tag=file_tag, xlabel='Ch2 Area (PE)', title='lv2414 ch2 s1')
# Out:
# Fit: mu= 2410.66, sigma =5.15

# %%
mean_ch0 = np.mean(area_ch0_s2)
std_ch0 = np.std(area_ch0_s2)
nbins_ch0 = round(np.max(area_ch0_s2)-np.min(area_ch0_s2))
left_edge_ch0 = np.min(area_ch0_s2)
right_edge_ch0 = np.max(area_ch0_s2)
amplitude_ch0 = len(area_ch0_s2)

mean_ch1 = np.mean(area_ch1_s2)
std_ch1 = np.std(area_ch1_s2)
nbins_ch1 = round(np.max(area_ch1_s2)-np.min(area_ch1_s2))
left_edge_ch1 = np.min(area_ch1_s2)
right_edge_ch1 = np.max(area_ch1_s2)
amplitude_ch1 = len(area_ch1_s2)

mean_ch2 = np.mean(-area_ch2_s2)
std_ch2 = np.std(-area_ch2_s2)
nbins_ch2 = round(np.max(-area_ch2_s2)-np.min(-area_ch2_s2))
left_edge_ch2 = np.min(-area_ch2_s2)
right_edge_ch2 = np.max(-area_ch2_s2)
amplitude_ch2 = len(-area_ch2_s2)

# %%
Ch0_s2_mu, Ch0_s2_sigma =  analysis_data.plot_fit_histgram_vs_Gaussion(area_ch0_s2, 100,left_edge_ch0, right_edge_ch0 , [amplitude_ch0, mean_ch0, std_ch0 ], file_tag=file_tag, xlabel='Ch0 Area (PE)', title='lv2414_ch0_s1',Save=False)
# Out:
# Fit: mu= 21175.58, sigma =122.12

# %%
Ch1_s2_mu, Ch1_s2_sigma =  analysis_data.plot_fit_histgram_vs_Gaussion(area_ch1_s2, 100, left_edge_ch1 , right_edge_ch1 , [amplitude_ch1, mean_ch1, std_ch1 ], file_tag=file_tag, xlabel='Ch1 Area (PE)', title='lv2414 Ch1 s1 ')
# Out:
# Fit: mu= 279.52, sigma =22.65

# %%
Ch2_s2_mu, Ch2_s2_sigma =  analysis_data.plot_fit_histgram_vs_Gaussion(-area_ch2_s2, 100, left_edge_ch2 ,right_edge_ch2, [amplitude_ch2, mean_ch2, std_ch2 ], file_tag=file_tag, xlabel='Ch2 Area (PE)', title='lv2414 ch2 s1')
# Out:
# Fit: mu= 260.98, sigma =7.61

# %%
run_info.append({
        'Ch0_s1_mu': Ch0_s1_mu,
        'Ch1_s1_mu': Ch1_s1_mu,
        'Ch2_s1_mu': Ch2_s1_mu,
        'Ch0_s2_mu': Ch0_s2_mu,
        'Ch1_s2_mu': Ch1_s2_mu,
        'Ch2_s2_mu': Ch2_s2_mu,
        'S1_width': df.S1_width.values[0],  #100 ns
        'S2_width': df.S2_width.values[0],  #ns
        'Delta_t' : df.Delta_t.values[0],  # us 
        'file_tag': file_tag,            
        'Ch0_s1_sigma' : Ch0_s1_sigma,
        'Ch1_s1_sigma' : Ch1_s1_sigma,
        'Ch2_s1_sigma' : Ch2_s1_sigma,
        'Ch0_s2_sigma' : Ch0_s2_sigma,
        'Ch1_s2_sigma' : Ch1_s2_sigma,
        'Ch2_s2_sigma' : Ch2_s2_sigma,
    })

# %%
df = pd.DataFrame(run_info)
df[0:]
# Out:
#       Ch0_s1_mu    Ch1_s1_mu    Ch2_s1_mu     Ch0_s2_mu   Ch1_s2_mu  \
# 0  23026.164747  2752.022021  2398.624590  20016.877556  249.498557
# 1  22555.978802  2754.516913  2422.955591  22972.112485  314.149199
# 2  22513.660520  2756.813895  2425.573267  23241.971500  322.643904
# 3  22895.522735  2758.404555  2406.509871  20869.753936  275.128834
# 4  22808.037504  2761.913136  2410.660134  21175.579351  279.517756
#
#     Ch2_s2_mu  S1_width  S2_width  Delta_t  \
# 0  234.886380       152       920        5
# 1  293.848417       152      1070       10
# 2  300.984863       152      1080       30
# 3  254.623754       152       920       90
# 4  260.980872       152       920      200
#
#                                        file_tag  Ch0_s1_sigma  Ch1_s1_sigma  \
# 0    20241113_12DB_1.6v_900mv_1p9_1p36_5us_run0     64.427243     53.188566
# 1   20241113_12DB_1.6v_900mv_1p9_1p36_10us_run0     62.532792     53.563132
# ...

# %%
# import process_data
# import pandas as pd
# # path = r'outnpy/{}.h5py'.format(file_tag)
# # path = 'outnpy/S1_1.6V_152ns_S2_1.36V_1us_delta_t_5us_to_200us.h5py'
# process_data.write_to_hdf5(df, path)
# Out:
# h5 Write Time: 0.01 s
# h5 File Size: 1.03 MB
# Save to outnpy/S1_1.6V_152ns_S2_1.36V_1us_delta_t_5us_to_200us.h5py
# (0.007589817047119141, 1081573)
